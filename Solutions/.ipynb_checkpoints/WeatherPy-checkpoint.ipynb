# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name

    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 600

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url =  f"{url}?q={city}&appid={weather_api_key}&units=metric"

    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

    # pause to avoid rate limiting
    time.sleep(1)

# Indicate that Data Loading is complete
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | georgetown
# Processing Record 2 of Set 1 | lihue
# Processing Record 3 of Set 1 | joshimath
# Processing Record 4 of Set 1 | tazacorte
# Processing Record 5 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 6 of Set 1 | ushuaia
# Processing Record 7 of Set 1 | blackmans bay
# Processing Record 8 of Set 1 | waitangi
# Processing Record 9 of Set 1 | atafu village
# Processing Record 10 of Set 1 | nagaur
# Processing Record 11 of Set 1 | forio
# Processing Record 12 of Set 1 | longyearbyen
# Processing Record 13 of Set 1 | ponta delgada
# Processing Record 14 of Set 1 | mar del plata
# Processing Record 15 of Set 1 | vorgashor
# Processing Record 16 of Set 1 | fomboni
# Processing Record 17 of Set 1 | kapa'a
# Processing Record 18 of Set 1 | hevie
# City not found. Skipping...
# Processing Record 19 of Set 1 | papao
# Processing Record 20 of Set 1 | puerto natales
# Processing Record 21 of Set 1 | grytviken
# Processing Record 22 of Set 1 | wailua homesteads
# Processing Record 23 of Set 1 | gwadar
# Processing Record 24 of Set 1 | batang
# Processing Record 25 of Set 1 | bilibino
# Processing Record 26 of Set 1 | kupang
# Processing Record 27 of Set 1 | port-aux-francais
# Processing Record 28 of Set 1 | fort bragg
# Processing Record 29 of Set 1 | adamstown
# Processing Record 30 of Set 1 | shimokizukuri
# Processing Record 31 of Set 1 | fuvahmulah
# City not found. Skipping...
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | tual
# Processing Record 34 of Set 1 | hastings
# Processing Record 35 of Set 1 | toga village
# City not found. Skipping...
# Processing Record 36 of Set 1 | enriquillo
# Processing Record 37 of Set 1 | fedorovka
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | tortoli
# Processing Record 40 of Set 1 | invercargill
# Processing Record 41 of Set 1 | timbiqui
# Processing Record 42 of Set 1 | olonkinbyen
# Processing Record 43 of Set 1 | heroica caborca
# Processing Record 44 of Set 1 | sao joao da barra
# Processing Record 45 of Set 1 | weno
# Processing Record 46 of Set 1 | amahai
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | papatowai
# Processing Record 49 of Set 1 | mossel bay
# Processing Record 50 of Set 1 | kimamba
# Processing Record 0 of Set 2 | orapa
# Processing Record 1 of Set 2 | bredasdorp
# Processing Record 2 of Set 2 | tazovsky
# Processing Record 3 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 4 of Set 2 | west island
# Processing Record 5 of Set 2 | yellowknife
# Processing Record 6 of Set 2 | puerto ayora
# Processing Record 7 of Set 2 | iqaluit
# Processing Record 8 of Set 2 | cidreira
# Processing Record 9 of Set 2 | punta arenas
# Processing Record 10 of Set 2 | huarmey
# Processing Record 11 of Set 2 | badger
# Processing Record 12 of Set 2 | la passe
# Processing Record 13 of Set 2 | st. john's
# Processing Record 14 of Set 2 | luau
# Processing Record 15 of Set 2 | tindouf
# Processing Record 16 of Set 2 | wayne
# Processing Record 17 of Set 2 | eydhafushi
# Processing Record 18 of Set 2 | ouarzazat
# Processing Record 19 of Set 2 | manay
# Processing Record 20 of Set 2 | kirakira
# Processing Record 21 of Set 2 | guigue
# Processing Record 22 of Set 2 | whangarei
# Processing Record 23 of Set 2 | jaciara
# Processing Record 24 of Set 2 | melo
# Processing Record 25 of Set 2 | carnarvon
# Processing Record 26 of Set 2 | phan rang-thap cham
# Processing Record 27 of Set 2 | kilinochchi
# Processing Record 28 of Set 2 | lamar
# Processing Record 29 of Set 2 | susuman
# Processing Record 30 of Set 2 | nishon tumani
# Processing Record 31 of Set 2 | ribeira grande
# Processing Record 32 of Set 2 | yuncheng
# Processing Record 33 of Set 2 | bisbee
# Processing Record 34 of Set 2 | udachny
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | codrington
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | hammerfest
# Processing Record 39 of Set 2 | owatonna
# Processing Record 40 of Set 2 | malango
# Processing Record 41 of Set 2 | cockburn town
# Processing Record 42 of Set 2 | afaahiti
# Processing Record 43 of Set 2 | talnakh
# Processing Record 44 of Set 2 | nahiyat ash shinafiyah
# Processing Record 45 of Set 2 | praia
# Processing Record 46 of Set 2 | pimentel
# Processing Record 47 of Set 2 | rada tilly
# Processing Record 48 of Set 2 | dakhla
# Processing Record 49 of Set 2 | mynamaki
# Processing Record 0 of Set 3 | berdigestyakh
# Processing Record 1 of Set 3 | port saint john's
# Processing Record 2 of Set 3 | klyuchi
# Processing Record 3 of Set 3 | cartagena
# Processing Record 4 of Set 3 | nuuk
# Processing Record 5 of Set 3 | anadyr
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | utrik
# Processing Record 8 of Set 3 | shimoda
# Processing Record 9 of Set 3 | biskupiec
# Processing Record 10 of Set 3 | thompson
# Processing Record 11 of Set 3 | bethel
# Processing Record 12 of Set 3 | dudinka
# Processing Record 13 of Set 3 | mount pearl
# Processing Record 14 of Set 3 | hamilton
# Processing Record 15 of Set 3 | touros
# Processing Record 16 of Set 3 | tsiombe
# Processing Record 17 of Set 3 | arauca
# Processing Record 18 of Set 3 | pervomaysk
# Processing Record 19 of Set 3 | hawaiian paradise park
# Processing Record 20 of Set 3 | college
# Processing Record 21 of Set 3 | margaret river
# Processing Record 22 of Set 3 | jamestown
# Processing Record 23 of Set 3 | aqadyr
# Processing Record 24 of Set 3 | lianzhou
# Processing Record 25 of Set 3 | constantia
# Processing Record 26 of Set 3 | igarka
# Processing Record 27 of Set 3 | edinburgh of the seven seas
# Processing Record 28 of Set 3 | iskateley
# Processing Record 29 of Set 3 | high river
# Processing Record 30 of Set 3 | rio grande
# Processing Record 31 of Set 3 | hami
# Processing Record 32 of Set 3 | nantucket
# Processing Record 33 of Set 3 | tura
# Processing Record 34 of Set 3 | dolinsk
# Processing Record 35 of Set 3 | ono
# Processing Record 36 of Set 3 | khandyga
# Processing Record 37 of Set 3 | lhasa
# Processing Record 38 of Set 3 | dunedin
# Processing Record 39 of Set 3 | yomju-up
# Processing Record 40 of Set 3 | misratah
# Processing Record 41 of Set 3 | katsuura
# Processing Record 42 of Set 3 | ust-nera
# Processing Record 43 of Set 3 | isafjordur
# Processing Record 44 of Set 3 | qaqortoq
# Processing Record 45 of Set 3 | pisco
# Processing Record 46 of Set 3 | severo-vostotchnyi bank
# Processing Record 47 of Set 3 | sinabang
# Processing Record 48 of Set 3 | callao
# Processing Record 49 of Set 3 | ilulissat
# Processing Record 0 of Set 4 | kitimat
# Processing Record 1 of Set 4 | harper
# Processing Record 2 of Set 4 | kavaratti
# Processing Record 3 of Set 4 | port mathurin
# Processing Record 4 of Set 4 | acapulco de juarez
# Processing Record 5 of Set 4 | whitehorse
# Processing Record 6 of Set 4 | san fernando de apure
# Processing Record 7 of Set 4 | hirara
# Processing Record 8 of Set 4 | nadym
# Processing Record 9 of Set 4 | vingt cinq
# City not found. Skipping...
# Processing Record 10 of Set 4 | saipan
# Processing Record 11 of Set 4 | tamanrasset
# Processing Record 12 of Set 4 | arraial do cabo
# Processing Record 13 of Set 4 | mejit
# Processing Record 14 of Set 4 | gloucester
# Processing Record 15 of Set 4 | port glaud
# City not found. Skipping...
# Processing Record 16 of Set 4 | coquimbo
# Processing Record 17 of Set 4 | petropavlivka
# Processing Record 18 of Set 4 | nicoya
# Processing Record 19 of Set 4 | mahina
# Processing Record 20 of Set 4 | palmer
# Processing Record 21 of Set 4 | imbituba
# Processing Record 22 of Set 4 | dwarka
# Processing Record 23 of Set 4 | princeville
# Processing Record 24 of Set 4 | bermeo
# Processing Record 25 of Set 4 | holualoa
# Processing Record 26 of Set 4 | petrozavodsk
# Processing Record 27 of Set 4 | preobrazheniye
# Processing Record 28 of Set 4 | zaragoza
# Processing Record 29 of Set 4 | alice springs
# Processing Record 30 of Set 4 | souillac
# Processing Record 31 of Set 4 | fortuna
# Processing Record 32 of Set 4 | el nido
# Processing Record 33 of Set 4 | horta
# Processing Record 34 of Set 4 | ebon
# Processing Record 35 of Set 4 | polyarnyy
# Processing Record 36 of Set 4 | kodiak
# Processing Record 37 of Set 4 | al kharijah
# Processing Record 38 of Set 4 | gisborne
# Processing Record 39 of Set 4 | salekhard
# Processing Record 40 of Set 4 | trujillo
# Processing Record 41 of Set 4 | morehead city
# Processing Record 42 of Set 4 | saint-philippe
# Processing Record 43 of Set 4 | bayanhongor
# Processing Record 44 of Set 4 | castillos
# Processing Record 45 of Set 4 | calama
# Processing Record 46 of Set 4 | port moresby
# Processing Record 47 of Set 4 | jabor
# Processing Record 48 of Set 4 | hithadhoo
# Processing Record 49 of Set 4 | timaru
# Processing Record 0 of Set 5 | port lincoln
# Processing Record 1 of Set 5 | acarau
# Processing Record 2 of Set 5 | campoverde
# Processing Record 3 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 4 of Set 5 | lerwick
# Processing Record 5 of Set 5 | bismarck
# Processing Record 6 of Set 5 | saldanha
# Processing Record 7 of Set 5 | chibougamau
# Processing Record 8 of Set 5 | suva
# Processing Record 9 of Set 5 | egilsstadir
# Processing Record 10 of Set 5 | peniche
# Processing Record 11 of Set 5 | vilyuchinsk
# Processing Record 12 of Set 5 | taiobeiras
# Processing Record 13 of Set 5 | ubinskoye
# Processing Record 14 of Set 5 | tiksi
# Processing Record 15 of Set 5 | ancud
# Processing Record 16 of Set 5 | greymouth
# Processing Record 17 of Set 5 | stanley
# Processing Record 18 of Set 5 | malmberget
# Processing Record 19 of Set 5 | kazlu ruda
# Processing Record 20 of Set 5 | vilyuysk
# Processing Record 21 of Set 5 | massenya
# Processing Record 22 of Set 5 | san patricio
# Processing Record 23 of Set 5 | ati
# Processing Record 24 of Set 5 | fisterra
# Processing Record 25 of Set 5 | vicuna mackenna
# Processing Record 26 of Set 5 | prince albert
# Processing Record 27 of Set 5 | giengen an der brenz
# Processing Record 28 of Set 5 | laguna
# Processing Record 29 of Set 5 | asosa
# Processing Record 30 of Set 5 | amos
# Processing Record 31 of Set 5 | cannonvale
# Processing Record 32 of Set 5 | umba
# Processing Record 33 of Set 5 | port said
# Processing Record 34 of Set 5 | barcelos
# Processing Record 35 of Set 5 | tchintabaraden
# Processing Record 36 of Set 5 | alo
# Processing Record 37 of Set 5 | miyang
# Processing Record 38 of Set 5 | cabo san lucas
# Processing Record 39 of Set 5 | songjianghe
# Processing Record 40 of Set 5 | kamba
# Processing Record 41 of Set 5 | mata-utu
# Processing Record 42 of Set 5 | enewetak
# Processing Record 43 of Set 5 | badr hunayn
# Processing Record 44 of Set 5 | minacu
# City not found. Skipping...
# Processing Record 45 of Set 5 | bratsk
# Processing Record 46 of Set 5 | fada
# Processing Record 47 of Set 5 | bairnsdale
# Processing Record 48 of Set 5 | chahar burj
# Processing Record 49 of Set 5 | ta`u
# Processing Record 0 of Set 6 | santander jimenez
# Processing Record 1 of Set 6 | mawu
# Processing Record 2 of Set 6 | magaria
# Processing Record 3 of Set 6 | san luis de la loma
# Processing Record 4 of Set 6 | brokopondo
# Processing Record 5 of Set 6 | weatherford
# Processing Record 6 of Set 6 | aswan
# Processing Record 7 of Set 6 | qurayyat
# Processing Record 8 of Set 6 | saint-pierre
# Processing Record 9 of Set 6 | fale old settlement
# Processing Record 10 of Set 6 | kalevala
# Processing Record 11 of Set 6 | opatija
# Processing Record 12 of Set 6 | sretensk
# Processing Record 13 of Set 6 | nichinan
# Processing Record 14 of Set 6 | daru
# Processing Record 15 of Set 6 | saveh
# Processing Record 16 of Set 6 | gebeit
# Processing Record 17 of Set 6 | flying fish cove
# Processing Record 18 of Set 6 | amurrio
# Processing Record 19 of Set 6 | diego de almagro
# Processing Record 20 of Set 6 | sangkhla buri
# Processing Record 21 of Set 6 | tevriz
# Processing Record 22 of Set 6 | ola
# Processing Record 23 of Set 6 | tuzha
# Processing Record 24 of Set 6 | akureyri
# Processing Record 25 of Set 6 | zouerate
# Processing Record 26 of Set 6 | hermanus
# Processing Record 27 of Set 6 | taro
# Processing Record 28 of Set 6 | queenstown
# Processing Record 29 of Set 6 | selfoss
# Processing Record 30 of Set 6 | gamba
# Processing Record 31 of Set 6 | guiberoua
# Processing Record 32 of Set 6 | kirensk
# Processing Record 33 of Set 6 | kingston
# Processing Record 34 of Set 6 | nemuro
# Processing Record 35 of Set 6 | oulainen
# Processing Record 36 of Set 6 | nagqu
# Processing Record 37 of Set 6 | priozersk
# Processing Record 38 of Set 6 | champerico
# Processing Record 39 of Set 6 | haiku-pauwela
# Processing Record 40 of Set 6 | kone
# Processing Record 41 of Set 6 | puerto palomas
# Processing Record 42 of Set 6 | menongue
# Processing Record 43 of Set 6 | aykhal
# Processing Record 44 of Set 6 | el hadjira
# Processing Record 45 of Set 6 | nasir
# Processing Record 46 of Set 6 | broome
# Processing Record 47 of Set 6 | qui nhon
# Processing Record 48 of Set 6 | port alfred
# Processing Record 49 of Set 6 | santa maria
# Processing Record 0 of Set 7 | vadso
# Processing Record 1 of Set 7 | goundam
# Processing Record 2 of Set 7 | clarksdale
# Processing Record 3 of Set 7 | benguela
# Processing Record 4 of Set 7 | san jose del guaviare
# Processing Record 5 of Set 7 | cargados carajos
# City not found. Skipping...
# Processing Record 6 of Set 7 | urangan
# Processing Record 7 of Set 7 | maumere
# Processing Record 8 of Set 7 | crane
# Processing Record 9 of Set 7 | abra pampa
# Processing Record 10 of Set 7 | geraldton
# Processing Record 11 of Set 7 | yuzhno-kurilsk
# Processing Record 12 of Set 7 | khabarovsk
# Processing Record 13 of Set 7 | revda
# Processing Record 14 of Set 7 | saint-pierre-du-mont
# Processing Record 15 of Set 7 | doka
# Processing Record 16 of Set 7 | ritchie
# Processing Record 17 of Set 7 | waingapu
# Processing Record 18 of Set 7 | niafunke
# Processing Record 19 of Set 7 | guerrero negro
# Processing Record 20 of Set 7 | bururi
# Processing Record 21 of Set 7 | lodja
# Processing Record 22 of Set 7 | ulsteinvik
# Processing Record 23 of Set 7 | praia da vitoria
# Processing Record 24 of Set 7 | darlington
# Processing Record 25 of Set 7 | harstad
# Processing Record 26 of Set 7 | aripuana
# Processing Record 27 of Set 7 | bilajer
# Processing Record 28 of Set 7 | mpongwe
# Processing Record 29 of Set 7 | mahdishahr
# Processing Record 30 of Set 7 | lipany
# Processing Record 31 of Set 7 | samokov
# Processing Record 32 of Set 7 | san jose village
# City not found. Skipping...
# Processing Record 33 of Set 7 | medicine hat
# Processing Record 34 of Set 7 | ankazoabo
# Processing Record 35 of Set 7 | linping
# Processing Record 36 of Set 7 | eureka
# Processing Record 37 of Set 7 | shetpe
# Processing Record 38 of Set 7 | andratx
# Processing Record 39 of Set 7 | patterson
# Processing Record 40 of Set 7 | lame
# Processing Record 41 of Set 7 | catriel
# Processing Record 42 of Set 7 | mayen abun
# City not found. Skipping...
# Processing Record 43 of Set 7 | poddebice
# Processing Record 44 of Set 7 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 7 | port macquarie
# Processing Record 46 of Set 7 | vila velha
# Processing Record 47 of Set 7 | kirovskoye
# Processing Record 48 of Set 7 | el jadid
# Processing Record 49 of Set 7 | sangin
# Processing Record 0 of Set 8 | iwanai
# Processing Record 1 of Set 8 | santana
# Processing Record 2 of Set 8 | ula
# Processing Record 3 of Set 8 | mirny
# Processing Record 4 of Set 8 | la foa
# Processing Record 5 of Set 8 | westport
# Processing Record 6 of Set 8 | port douglas
# Processing Record 7 of Set 8 | antsiranana
# Processing Record 8 of Set 8 | arawa
# Processing Record 9 of Set 8 | maughold
# Processing Record 10 of Set 8 | la'ie
# Processing Record 11 of Set 8 | rawai
# Processing Record 12 of Set 8 | jos
# Processing Record 13 of Set 8 | laurentides
# Processing Record 14 of Set 8 | lambarene
# Processing Record 15 of Set 8 | lospalos
# Processing Record 16 of Set 8 | xinghua
# Processing Record 17 of Set 8 | la paz
# Processing Record 18 of Set 8 | port elizabeth
# Processing Record 19 of Set 8 | san antonio de pale
# Processing Record 20 of Set 8 | novyy urgal
# Processing Record 21 of Set 8 | barh
# Processing Record 22 of Set 8 | saint-francois
# Processing Record 23 of Set 8 | carentan
# Processing Record 24 of Set 8 | halifax
# Processing Record 25 of Set 8 | flin flon
# Processing Record 26 of Set 8 | santa ana
# Processing Record 27 of Set 8 | fortaleza
# Processing Record 28 of Set 8 | ormond-by-the-sea
# Processing Record 29 of Set 8 | taoudenni
# Processing Record 30 of Set 8 | belize city
# Processing Record 31 of Set 8 | katsuren-haebaru
# Processing Record 32 of Set 8 | nsanje
# Processing Record 33 of Set 8 | aldama
# Processing Record 34 of Set 8 | siavonga
# Processing Record 35 of Set 8 | lintong
# Processing Record 36 of Set 8 | jobner
# Processing Record 37 of Set 8 | zhezqazghan
# Processing Record 38 of Set 8 | tsetserleg
# Processing Record 39 of Set 8 | telavi
# Processing Record 40 of Set 8 | viqueque
# Processing Record 41 of Set 8 | berriane
# Processing Record 42 of Set 8 | ocean shores
# Processing Record 43 of Set 8 | greenville
# Processing Record 44 of Set 8 | turnov
# Processing Record 45 of Set 8 | mount isa
# Processing Record 46 of Set 8 | houmt el souk
# Processing Record 47 of Set 8 | uturoa
# Processing Record 48 of Set 8 | nesebar
# Processing Record 49 of Set 8 | talcahuano
# Processing Record 0 of Set 9 | darwin
# Processing Record 1 of Set 9 | sanchazi
# Processing Record 2 of Set 9 | iquique
# Processing Record 3 of Set 9 | namibe
# Processing Record 4 of Set 9 | kangding
# Processing Record 5 of Set 9 | kerikeri
# Processing Record 6 of Set 9 | vrangel'
# Processing Record 7 of Set 9 | al kut
# Processing Record 8 of Set 9 | baturaja
# Processing Record 9 of Set 9 | jayapura
# Processing Record 10 of Set 9 | gazipasa
# Processing Record 11 of Set 9 | labrador city
# Processing Record 12 of Set 9 | metkovic
# Processing Record 13 of Set 9 | matoury
# Processing Record 14 of Set 9 | illizi
# Processing Record 15 of Set 9 | el calafate
# Processing Record 16 of Set 9 | saudarkrokur
# Processing Record 17 of Set 9 | berrotaran
# Processing Record 18 of Set 9 | garachico
# Processing Record 19 of Set 9 | beylikova
# Processing Record 20 of Set 9 | bac lieu
# Processing Record 21 of Set 9 | benjamin constant
# Processing Record 22 of Set 9 | makokou
# Processing Record 23 of Set 9 | berezovo
# Processing Record 24 of Set 9 | yakeshi
# Processing Record 25 of Set 9 | mulanje
# Processing Record 26 of Set 9 | chabahar
# Processing Record 27 of Set 9 | valentin gomez farias
# Processing Record 28 of Set 9 | vila franca do campo
# Processing Record 29 of Set 9 | argostolion
# Processing Record 30 of Set 9 | aasiaat
# Processing Record 31 of Set 9 | tonekabon
# Processing Record 32 of Set 9 | aleshtar
# Processing Record 33 of Set 9 | floro
# Processing Record 34 of Set 9 | mahanoro
# Processing Record 35 of Set 9 | khovd
# Processing Record 36 of Set 9 | ojinaga
# Processing Record 37 of Set 9 | portland
# Processing Record 38 of Set 9 | zahedan
# Processing Record 39 of Set 9 | tupiza
# Processing Record 40 of Set 9 | hualien city
# Processing Record 41 of Set 9 | yemva
# Processing Record 42 of Set 9 | trincomalee
# Processing Record 43 of Set 9 | calvinia
# Processing Record 44 of Set 9 | kununurra
# Processing Record 45 of Set 9 | joao pinheiro
# Processing Record 46 of Set 9 | szczytno
# Processing Record 47 of Set 9 | dhidhdhoo
# Processing Record 48 of Set 9 | sisimiut
# Processing Record 49 of Set 9 | okha
# Processing Record 0 of Set 10 | sao tome
# Processing Record 1 of Set 10 | gadzhiyevo
# Processing Record 2 of Set 10 | east london
# Processing Record 3 of Set 10 | sitka
# Processing Record 4 of Set 10 | arteche
# Processing Record 5 of Set 10 | sao felix do xingu
# Processing Record 6 of Set 10 | carutapera
# Processing Record 7 of Set 10 | abraham's bay
# City not found. Skipping...
# Processing Record 8 of Set 10 | dongtai
# Processing Record 9 of Set 10 | santa terezinha
# Processing Record 10 of Set 10 | zhanaozen
# Processing Record 11 of Set 10 | isabela
# Processing Record 12 of Set 10 | hawera
# Processing Record 13 of Set 10 | khenifra
# Processing Record 14 of Set 10 | riyadh
# Processing Record 15 of Set 10 | yueyang
# Processing Record 16 of Set 10 | sittwe
# Processing Record 17 of Set 10 | lorengau
# Processing Record 18 of Set 10 | ishigaki
# Processing Record 19 of Set 10 | odienne
# Processing Record 20 of Set 10 | newman
# Processing Record 21 of Set 10 | 'ohonua
# City not found. Skipping...
# Processing Record 22 of Set 10 | kapuskasing
# Processing Record 23 of Set 10 | el porvenir
# Processing Record 24 of Set 10 | shakawe
# Processing Record 25 of Set 10 | prieska
# Processing Record 26 of Set 10 | sao joao de pirabas
# Processing Record 27 of Set 10 | shukat as sufi
# Processing Record 28 of Set 10 | kismayo
# Processing Record 29 of Set 10 | onguday
# Processing Record 30 of Set 10 | kwatarkwashi
# Processing Record 31 of Set 10 | al majaridah
# Processing Record 32 of Set 10 | tepic
# Processing Record 33 of Set 10 | thunder bay
# Processing Record 34 of Set 10 | fort mcmurray
# Processing Record 35 of Set 10 | korhogo
# Processing Record 36 of Set 10 | decatur
# Processing Record 37 of Set 10 | riohacha
# Processing Record 38 of Set 10 | chicxulub puerto
# City not found. Skipping...
# Processing Record 39 of Set 10 | al 'alamayn
# City not found. Skipping...
# Processing Record 40 of Set 10 | nguigmi
# Processing Record 41 of Set 10 | uyuni
# Processing Record 42 of Set 10 | 'ibri
# City not found. Skipping...
# Processing Record 43 of Set 10 | sambava
# Processing Record 44 of Set 10 | dunda
# Processing Record 45 of Set 10 | onverwacht
# Processing Record 46 of Set 10 | kinel'-cherkassy
# Processing Record 47 of Set 10 | geneseo
# Processing Record 48 of Set 10 | yagry
# City not found. Skipping...
# Processing Record 49 of Set 10 | iquitos
# Processing Record 0 of Set 11 | illapel
# Processing Record 1 of Set 11 | howrah
# Processing Record 2 of Set 11 | kimbe
# Processing Record 3 of Set 11 | quellon
# Processing Record 4 of Set 11 | mudkhed
# Processing Record 5 of Set 11 | ashland
# Processing Record 6 of Set 11 | caucete
# Processing Record 7 of Set 11 | tonghae
# Processing Record 8 of Set 11 | valle hermoso
# Processing Record 9 of Set 11 | shipunovo
# Processing Record 10 of Set 11 | nizhneangarsk
# Processing Record 11 of Set 11 | lalupon
# Processing Record 12 of Set 11 | owase
# Processing Record 13 of Set 11 | ginir
# Processing Record 14 of Set 11 | scottburgh
# Processing Record 15 of Set 11 | prado
# Processing Record 16 of Set 11 | tolanaro
# Processing Record 17 of Set 11 | coahuayana de hidalgo
# Processing Record 18 of Set 11 | ibiza
# Processing Record 19 of Set 11 | bhamo
# Processing Record 20 of Set 11 | askoy
# Processing Record 21 of Set 11 | zhangye
# Processing Record 22 of Set 11 | mount gambier
# Processing Record 23 of Set 11 | quatre cocos
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | erenhot
# Processing Record 26 of Set 11 | huanggang
# Processing Record 27 of Set 11 | paramonga
# Processing Record 28 of Set 11 | t'ongch'on-up
# Processing Record 29 of Set 11 | camacupa
# Processing Record 30 of Set 11 | grand-lahou
# Processing Record 31 of Set 11 | rong kwang
# Processing Record 32 of Set 11 | chonchi
# Processing Record 33 of Set 11 | beloyarskiy
# Processing Record 34 of Set 11 | xinzhi
# Processing Record 35 of Set 11 | seaside
# Processing Record 36 of Set 11 | hadibu
# Processing Record 37 of Set 11 | chebba
# Processing Record 38 of Set 11 | prata
# Processing Record 39 of Set 11 | olgii
# City not found. Skipping...
# Processing Record 40 of Set 11 | al hazm
# Processing Record 41 of Set 11 | lazaro cardenas
# Processing Record 42 of Set 11 | mandiana
# Processing Record 43 of Set 11 | keflavik
# Processing Record 44 of Set 11 | arak
# Processing Record 45 of Set 11 | najran
# Processing Record 46 of Set 11 | san francisco ixhuatan
# Processing Record 47 of Set 11 | puri
# Processing Record 48 of Set 11 | kulhudhuffushi
# Processing Record 49 of Set 11 | labytnangi
# Processing Record 0 of Set 12 | mangalam
# Processing Record 1 of Set 12 | grootfontein
# Processing Record 2 of Set 12 | pyay
# Processing Record 3 of Set 12 | gizo
# Processing Record 4 of Set 12 | urbana
# Processing Record 5 of Set 12 | elverum
# Processing Record 6 of Set 12 | zhalantun
# Processing Record 7 of Set 12 | banswara
# Processing Record 8 of Set 12 | mwene-ditu
# Processing Record 9 of Set 12 | levelland
# Processing Record 10 of Set 12 | cam ranh
# Processing Record 11 of Set 12 | igrim
# Processing Record 12 of Set 12 | freetown
# Processing Record 13 of Set 12 | valozhyn
# Processing Record 14 of Set 12 | tubarjal
# Processing Record 15 of Set 12 | elmendorf air force base
# City not found. Skipping...
# Processing Record 16 of Set 12 | buka
# Processing Record 17 of Set 12 | les cayes
# Processing Record 18 of Set 12 | tralee
# Processing Record 19 of Set 12 | new norfolk
# Processing Record 20 of Set 12 | general acha
# Processing Record 21 of Set 12 | kristiansund
# Processing Record 22 of Set 12 | nema
# Processing Record 23 of Set 12 | tan-tan
# Processing Record 24 of Set 12 | mozarlandia
# Processing Record 25 of Set 12 | znamenskoye
# Processing Record 26 of Set 12 | vydrino
# Processing Record 27 of Set 12 | richards bay
# Processing Record 28 of Set 12 | pazaryeri
# Processing Record 29 of Set 12 | bardai
# Processing Record 30 of Set 12 | hovd
# Processing Record 31 of Set 12 | rabo de peixe
# Processing Record 32 of Set 12 | marshalltown
# Processing Record 33 of Set 12 | karratha
# Processing Record 34 of Set 12 | alofi
# Processing Record 35 of Set 12 | zaranj
# Processing Record 36 of Set 12 | senanga
# Processing Record 37 of Set 12 | howard springs
# Processing Record 38 of Set 12 | kayangel
# Processing Record 39 of Set 12 | nova xavantina
# Processing Record 40 of Set 12 | ghanzi
# Processing Record 41 of Set 12 | kourou
# Processing Record 42 of Set 12 | gazojak
# Processing Record 43 of Set 12 | caleta olivia
# Processing Record 44 of Set 12 | samana
# Processing Record 45 of Set 12 | anqing
# Processing Record 46 of Set 12 | bandon
# Processing Record 47 of Set 12 | puerto colombia
# Processing Record 48 of Set 12 | carolina beach
# Processing Record 49 of Set 12 | argo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          580
# Lat           580
# Lng           580
# Max Temp      580
# Humidity      580
# Cloudiness    580
# Wind Speed    580
# Country       580
# Date          580
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  georgetown   5.4112  100.3354     29.96        80          20        1.54
# 1       lihue  21.9789 -159.3672     27.77        68          20        6.17
# 2   joshimath  30.5667   79.5667     18.33       100         100        1.22
# 3   tazacorte  28.6290  -17.9293     22.54        73         100        7.20
# 4     ushuaia -54.8000  -68.3000      4.81        70          75        9.26
#
#   Country        Date
# 0      MY  1721612045
# 1      US  1721612290
# 2      IN  1721612291
# 3      ES  1721612292
# 4      AR  1721611691

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        georgetown   5.4112  100.3354     29.96        80          20
# 1             lihue  21.9789 -159.3672     27.77        68          20
# 2         joshimath  30.5667   79.5667     18.33       100         100
# 3         tazacorte  28.6290  -17.9293     22.54        73         100
# 4           ushuaia -54.8000  -68.3000      4.81        70          75
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      MY  1721612045
# 1              6.17      US  1721612290
# 2              1.22      IN  1721612291
# 3              7.20      ES  1721612292
# 4              9.26      AR  1721611691

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Lat"], city_data_df["Max Temp"], edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (C)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Lat"], city_data_df["Humidity"], edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Lat"], city_data_df["Cloudiness"], edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Lat"], city_data_df["Wind Speed"], edgecolor="black")

# Incorporate the other graph properties
plt.title("City Latitude Vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Windspeed (m/s)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def linear_regression_plot(x_axis, y_axis, title, formula):
    
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_axis, y_axis)
    regression_values = x_axis * slope + intercept
    line_equation = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_axis, y_axis)
    plt.plot(x_axis, regression_values, "r-")
    plt.annotate(line_equation, formula, fontsize=15, color="red")
    plt.xlabel("Latitude")
    plt.ylabel(title)
    plt.title("Latitude vs " + title)
    print(f"The r^2-value is: {rvalue}")
    plt.show()

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        georgetown   5.4112  100.3354     29.96        80          20
# 1             lihue  21.9789 -159.3672     27.77        68          20
# 2         joshimath  30.5667   79.5667     18.33       100         100
# 3         tazacorte  28.6290  -17.9293     22.54        73         100
# 8            nagaur  27.2000   73.7333     30.85        62           3
#
#          Wind Speed Country        Date
# City_ID
# 0              1.54      MY  1721612045
# 1              6.17      US  1721612290
# 2              1.22      IN  1721612291
# 3              7.20      ES  1721612292
# 8              3.35      IN  1721612299

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                   City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4              ushuaia -54.8000  -68.3000      4.81        70          75
# 5        blackmans bay -43.0167  147.3167     14.74        76          92
# 6             waitangi -43.9535 -176.5597     10.46        99         100
# 7        atafu village  -8.5421 -172.5159     28.35        72           1
# 12       mar del plata -38.0023  -57.5575      7.71        89           0
#
#          Wind Speed Country        Date
# City_ID
# 4              9.26      AR  1721611691
# 5              0.45      AU  1721612296
# 6              5.81      NZ  1721612297
# 7              9.29      TK  1721612298
# 12             0.89      AR  1721612282

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_axis = northern_hemi_df ["Lat"]
y_axis = northern_hemi_df ["Max Temp"]
linear_regression_plot(x_axis, y_axis, "Max Temp", (0, 5))
# Out:
# The r^2-value is: -0.6276196669398921

# %%
# Linear regression on Southern Hemisphere
x_axis = southern_hemi_df ["Lat"]
y_axis = southern_hemi_df ["Max Temp"]
linear_regression_plot(x_axis, y_axis, "Max Temp", (-50, 25))
# Out:
# The r^2-value is: 0.7571077206308189

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression on the Northern Hemisphere for "Latitude vs Max Temp" shows a moderate negative correlation at -0.62. The linear regression on the Southern Hemisphere for "Latitude vs Max Temp" shows a strong correlation at 0.75.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df ["Lat"]
y_axis = northern_hemi_df ["Humidity"]
linear_regression_plot(x_axis, y_axis, "Humidity", (45, 20))
# Out:
# The r^2-value is: -0.0956486393531911

# %%
# Southern Hemisphere
x_axis = southern_hemi_df ["Lat"]
y_axis = southern_hemi_df ["Humidity"]
linear_regression_plot(x_axis, y_axis, "Humidity", (-55, 20))
# Out:
# The r^2-value is: -0.08671783441664657

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression for "Latitude vs Humidity" on both the northern and southern hemispheres show almost no correlation. The northern hemisphere shows -0.09 correlation and the southern hemisphere shows -0.08 correlation.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df ["Lat"]
y_axis = northern_hemi_df ["Cloudiness"]
linear_regression_plot(x_axis, y_axis, "Cloudiness", (0, 45))
# Out:
# The r^2-value is: -0.07490699410391813

# %%
# Southern Hemisphere
x_axis = southern_hemi_df ["Lat"]
y_axis = southern_hemi_df ["Cloudiness"]
linear_regression_plot(x_axis, y_axis, "Cloudiness", (-55, 20))
# Out:
# The r^2-value is: -0.1434737076839945

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression for "Latitude vs Cloudiness" on both the northern and southern hemispheres show almost no correlation. The northern hemisphere shows -0.07 correlation and the southern hemisphere shows -0.14 correlation.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_axis = northern_hemi_df ["Lat"]
y_axis = northern_hemi_df ["Wind Speed"]
linear_regression_plot(x_axis, y_axis, "Wind Speed", (20, 12))
# Out:
# The r^2-value is: -0.0910732893186971

# %%
# Southern Hemisphere
x_axis = southern_hemi_df ["Lat"]
y_axis = southern_hemi_df ["Wind Speed"]
linear_regression_plot(x_axis, y_axis, "Wind Speed", (-25, 15))
# Out:
# The r^2-value is: -0.12308529918196034

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression for "Latitude vs Wind Speed" on both the northern and southern hemispheres show almost no correlation. The northern hemisphere shows -0.09 correlation and the southern hemisphere shows -0.12 correlation.
